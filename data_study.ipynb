# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.1.2; however, version 21.2.3 is available.
# You should consider upgrading via the '/home/drapaiton/.cache/pypoetry/virtualenvs/mini-proyecto-next-e-FxB7tOun-py3.9/bin/python -m pip install --upgrade pip' command.
# ...
#      |████████████████████████████████| 10.3 MB 1.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 1.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.0 MB 1.6 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.1.2; however, version 21.2.3 is available.
# You should consider upgrading via the '/home/drapaiton/.cache/pypoetry/virtualenvs/mini-proyecto-next-e-FxB7tOun-py3.9/bin/python -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
"""extracted forecasts from 2021-08-10 14:00:00 to 2021-08-13 06:00:00"""

df = pd.DataFrame.from_records({
    "clouds": {
        "count": 60.0,
        "mean": 31.783333333333335,
        "std": 28.375264751496402,
        "min": 0.0,
        "25%": 5.75,
        "50%": 27.0,
        "75%": 52.25,
        "max": 100.0
    },
    "humidity": {
        "count": 60.0,
        "mean": 54.61666666666667,
        "std": 17.370432375273644,
        "min": 26.0,
        "25%": 38.0,
        "50%": 57.0,
        "75%": 68.25,
        "max": 88.0
    },
    "pressure": {
        "count": 60.0,
        "mean": 1014.8166666666667,
        "std": 1.8179115104666141,
        "min": 1011.0,
        "25%": 1013.0,
        "50%": 1015.0,
        "75%": 1016.0,
        "max": 1018.0
    },
    "visibility": {
        "count": 60.0,
        "mean": 10000.0,
        "std": 0.0,
        "min": 10000.0,
        "25%": 10000.0,
        "50%": 10000.0,
        "75%": 10000.0,
        "max": 10000.0
    },
    "wind_deg": {
        "count": 60.0,
        "mean": 108.23333333333333,
        "std": 18.505488573518743,
        "min": 39.0,
        "25%": 103.0,
        "50%": 113.0,
        "75%": 121.25,
        "max": 138.0
    }
})
df
# Out:
#            clouds   humidity     pressure  visibility    wind_deg
# count   60.000000  60.000000    60.000000        60.0   60.000000
# mean    31.783333  54.616667  1014.816667     10000.0  108.233333
# std     28.375265  17.370432     1.817912         0.0   18.505489
# min      0.000000  26.000000  1011.000000     10000.0   39.000000
# 25%      5.750000  38.000000  1013.000000     10000.0  103.000000
# 50%     27.000000  57.000000  1015.000000     10000.0  113.000000
# 75%     52.250000  68.250000  1016.000000     10000.0  121.250000
# max    100.000000  88.000000  1018.000000     10000.0  138.000000

# %%
df['clouds'].plot()
# Out:
# <AxesSubplot:>

# %%
df['wind_deg'].plot()
# Out:
# <AxesSubplot:>

# %%
df['visibility'].plot()
# Out:
# <AxesSubplot:>

# %%
df['pressure'].plot()
# Out:
# <AxesSubplot:>

# %%
df['humidity'].plot()
# Out:
# <AxesSubplot:>
